# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "2015.csv"
data_frame = pd.read_csv(path)
data_frame
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Crea histogramas para las variables Score, GDP per capita, Healthy life expectancy y Freedom to make life choices.
data_frame['Happiness Score'].hist(bins=20, alpha=0.7, color='green', edgecolor='black')
plt.title('Distribución de Happiness Score')
plt.xlabel('Happiness Score')
plt.ylabel('Frecuencia')
plt.show()

# Analisis del grafico de puntaje de felicidad 
# Se observa  que el puntaje de felicidad es entre 4 y 6 en la mayoria de las personas

data_frame['Economy (GDP per Capita)'].hist(bins=20, alpha=0.7 , color='blue',edgecolor='black')
plt.title('Distribución de GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Frecuencia')
plt.show()

# Se observa que el per capita  de los paises con mayor GDP es entre 100 y 150 millones de dólares

data_frame['Health (Life Expectancy)'].hist(bins=20, alpha=0.7 , color="orange",edgecolor='black')
plt.title('Distribución de Healthy Life Expectancy')
plt.xlabel('Healthy Life Expectancy')
plt.ylabel('Frecuencia')
plt.show()

data_frame['Freedom'].hist(bins=20, alpha=0.7, color="lightblue",edgecolor='black')
plt.title('Distribución de Freedom to Make Life Choices')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Frecuencia')
plt.show()

# %%
#Crea boxplots para las mismas variables para visualizar la mediana, el rango intercuartil y los valores atípicos.
variables = ['Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom']
data_frame[variables].boxplot()
plt.title('Boxplots de Happiness Score, GDP per Capita, Healthy Life Expectancy y Freedom')
plt.xlabel('Distribucion general ')
plt.ylabel('Valores')
plt.xticks(rotation=45)
plt.show()

# %%
# Combina los histogramas y los boxplots en una sola figura para cada variable.
fig, axes = plt.subplots(len(variables), 2, figsize=(10, 16))

for i, var in enumerate(variables):
    # Histograma
    data_frame[var].hist(ax=axes[i, 0], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
    axes[i, 0].set_title(f'Histograma de {var}')
    axes[i, 0].set_xlabel(var)
    axes[i, 0].set_ylabel('Frecuencia')
    
    # Boxplot
    axes[i, 1].boxplot(data_frame[var], vert=False)
    axes[i, 1].set_title(f'Boxplot de {var}')
    axes[i, 1].set_xlabel(var)

plt.tight_layout()
plt.show()

# %%
# Análisis de las distribuciones:

# Happiness Score: La distribución del puntaje de felicidad muestra que la mayoría de los países tienen valores entre 4 y 6, con pocos países en los extremos. 
# El boxplot indica una mediana clara y algunos valores atípicos en ambos extremos, lo que sugiere que existen países significativamente más felices o menos felices que el promedio.

# Economy (GDP per Capita): La distribución es asimétrica hacia la derecha, con la mayoría de los países concentrados en valores bajos de PIB per cápita y unos pocos con valores muy altos. 
# El boxplot revela varios valores atípicos en el extremo superior, correspondientes a países con economías muy desarrolladas.

# Health (Life Expectancy): La mayoría de los países se agrupan en valores medios-altos de esperanza de vida saludable. 
# El boxplot muestra una mediana elevada y algunos valores atípicos en el extremo inferior, lo que indica que pocos países tienen una esperanza de vida significativamente menor.

# Freedom: La variable libertad presenta una distribución relativamente uniforme, aunque con una ligera concentración en valores medios. 
# El boxplot muestra algunos valores atípicos bajos, lo que sugiere que ciertos países tienen niveles de libertad notablemente inferiores al resto.

# Conclusion:
#  las variables presentan distribuciones variadas y la presencia de valores atípicos indica diferencias significativas entre países en cada aspecto analizado.
